# %% [markdown]
# **Limpeza**: Para limpar os dados, precisamos trabalhar com:
#  - os valores faltantes: dispneia, febre e tosse no nosso caso (vamos remover).
#  - Valores especiais: Variáveis numericas podem ter varios valores especiais formatados, como +/- Inf, NA e NaN, ou textuais com caracteres especiais.
#  - Pontos fora da curva: Deve-se detectar, mas não necessariamente remover. A sua inclusão ou exclusão é uma decisão estatística. (Não temos esse caso no nosso conjunto de dados).
#  - Iconsistências obvias: Alguém não pode ter inicio dos sintomas após a data atual. Alguém não pode estar em óbito e recuperado. (Não temos esse caso no nosso conjunto de dados).
#
#
# **Engenharia**: Também chamada de Mineração, e existem algumas tecnicas como:
#  - Decompozição: Converter uma data 2021-03-18T18:23:50 em outros campos categoricos como hora_do_dia, periodo_do_dia, etc (Podemos extrair de 'CONDICOES')
#  - Discretização: Em alguns casos, pode-se discretizar algumas variaveis continuas que se tem, para que algoritmos performem mais rapidamente (Não aplicável aos nossos dados)
#  - Mudar quantidades numericas: Mudar gramas para kg, mudar h para dias. Perdendo algum detalhe mas pode ajudar em calculos
#  - Cruzamento de caracteristica: Criar novas caracteristicas (*features*) como uma combinação de características existentes. Pode ser multiplicar variaveis numericas, ou mesmo combinar variaveis categoricas. É uma boa maneira de adicionar conhecimento especializado ao conjunto de dados.
#
#
# A **transformação** de dados, dentro da engenharia, refere-se aos processos que convergem em uma reestruturação dos dados a partir das fontes originais. Em outras palavras, o objetivo da transformação é, partindo de um estado complexo e ilegível dos dados originais, apresentar os dados em novos formatos e estruturas que facilitema análise e a geração de *insights*.

# %% [markdown]
# ## 0. Carregamento das bibliotecas

# %%
# pacotes padrao
import os, sys, types, time, datetime, math, random, unidecode

# Para nuvem de palavras
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# Manipulacao de dados
import numpy as np
import pandas as pd

# Visualizacao de dados
import matplotlib.pyplot as plt
import missingno as msno
import seaborn as sns

# Lidando com Warnings 
import warnings
warnings.filterwarnings('ignore')

# plotagem Inline
# %matplotlib inline

# %% [markdown]
# ## 1. Carregamento dos dados

# %%
df = pd.read_csv("files/20210311.csv", sep=';')

# %% [markdown]
# ## 2. Limpeza, engenharia e transformação

# %% [markdown]
# #### 2.1 Remoção das colunas que não utilizaremos
#
# Como visto na exploração dos dados, existem algumas colunas que não agregam informação com relação ao nosso objetivo (prever a chance de óbito); portanto removeremos estas colunas, e selecionaremos apenas o conjunto de dados que nos interessa.

# %%
df.drop(columns=['COD_IBGE', 'MUNICIPIO', 'COD_REGIAO_COVID', 'REGIAO_COVID',
                 'FONTE_INFORMACAO', 'BAIRRO', 'PAIS_NASCIMENTO', 'PES_PRIV_LIBERDADE', 
                 'PROFISSIONAL_SAUDE', 'DATA_EVOLUCAO', 'DATA_CONFIRMACAO', 'DATA_SINTOMAS', 
                 'DATA_INCLUSAO_OBITO', 'HOSPITALIZACAO_SRAG', 'HOSPITALIZADO',
                 'DATA_EVOLUCAO_ESTIMADA', 'ETNIA_INDIGENA', 'CRITERIO', 'OUTROS'], inplace=True)

df.columns
# Out:
# Index(['SEXO', 'FAIXAETARIA', 'EVOLUCAO', 'FEBRE', 'TOSSE', 'GARGANTA',
#        'DISPNEIA', 'CONDICOES', 'GESTANTE', 'RACA_COR'],
#       dtype='object')

# %% [markdown]
# #### 2.2 Remoção dos registros (linhas) com dados faltantes

# %%
df.dropna(axis=0, how='any', inplace=True)

# %%
print((df.isnull().sum() / df.shape[0]).sort_values(ascending=False) * 100)
# Out:
# RACA_COR       0.0
# GESTANTE       0.0
# CONDICOES      0.0
# DISPNEIA       0.0
# GARGANTA       0.0
# TOSSE          0.0
# FEBRE          0.0
# EVOLUCAO       0.0
# FAIXAETARIA    0.0
# SEXO           0.0
# dtype: float64

# %% [markdown]
# #### 2.3 Engenharia/transformação dos dados

# %% [markdown]
# **Variável: ```EVOLUCAO```**
#
# Como queremos prever os casos que evoluíram para óbito por COVID, precisamos dos dados que estão com EVOLUCAO = 'OBITO', e também dos não-óbito (RECUPERADO).
# Para isso, vamos selecionar a fatia dos dados que possuem evolucao como 'OBITO' ou 'RECUPERADO', apenas.

# %%
df = df[(df['EVOLUCAO'] == 'OBITO') | (df['EVOLUCAO'] == 'RECUPERADO')]

# %% [markdown]
# Após selecionar os dados com a evolução que precisamos, vamos mudar o nome da variavel e transformar óbito para 1 e recuperado para 0.

# %%
df.rename(columns={'EVOLUCAO': 'OBITO'}, inplace=True)
df['OBITO'] = df['OBITO'].map({'OBITO': 1, 'RECUPERADO': 0})

# %% [markdown]
# **Variável: ```CONDICOES```**
#
# Visualização de uma nuvem de palavras
#
# Vamos extrair os dados da coluna `CONDICOES`, primeiramente visualizando uma nuvem de palavras para entendermos as condições ali presentes.
#
# Para isso, precisamos de 3 passos:
#  - 1) Remoção dos valores faltantes: O primeiro comando que deve ser executado é a remoção das linhas onde apresentam dados ausentes na coluna 'CONDICOES', já que nesta variável encontra-se os textos utilizados para realizar o *wordcloud*.
#  - 2) Transformar em caixa baixa e remover acentos
#  - 3) Junção das strings: Após a remoção das linhas, precisamos unir todas as palavras em uma única *string*.
#  - 4) Eliminar *stopwords*: Para criação de nuvem de palavras, algumas preposições ou palavras devem ser removidas (*e.g.*, do, da, dos, das, no).

# %%
df.dropna(subset=['CONDICOES'], axis=0, inplace=True) # remocao das linhas faltantes

for col in df.drop('OBITO', axis=1).columns:
    df[col] = df[col].apply(unidecode.unidecode) # removendo acentos
    
df['CONDICOES'] = df['CONDICOES'].apply(str.lower) # deixando caixa baixa

conditions = df['CONDICOES'] # pegar apenas as condicoes
all_words_conditions = " ".join(s for s in conditions) # unir tudo em uma string

stopwords = set(STOPWORDS)
stopwords.update(["da", "meu", "em", "de", "ao", "os", "ou", 
                  'outros', 'outro', 'outra', 'ate', 'doenca', 'doencas']) # acréscimo de mais stopwords

wordcloud = WordCloud(stopwords=stopwords,
                      background_color='white', width=1280,                            
                      height=720).generate(all_words_conditions)

fig, ax = plt.subplots(figsize=(16,10))            
ax.imshow(wordcloud, interpolation='bilinear')       
ax.set_axis_off()

plt.imshow(wordcloud)                 
wordcloud.to_file('condicoes.png',);

# %%
import collections
import re

wordcount = collections.defaultdict(int)
pattern = r"\W"
for word in all_words_conditions.split():
    #word = re.sub(pattern, '', word)
    if word not in stopwords:
        wordcount[word] += 1

mc = sorted(wordcount.items(), key=lambda k_v: k_v[1], reverse=True)[:50]

# %%
for word, count in mc:
    print(word, ":", count)
# Out:
# cronicas : 39868
# cardiacas : 31911
# diabetes : 23784
# cronica, : 17738
# cardiovascular : 16909
# respiratorias : 12326
# descompensadas : 10217
# cronica : 8123
# mellitus, : 7186
# obesidade : 6241
# cronicas, : 5717
# mellitus : 4722
# diabetes, : 3829
# pneumatopatia : 2967
# neurologica : 2935
# gestante : 2905
# imunossupressao : 2591
# obesidade, : 2172
# descompensadas, : 2109
# renal : 2107
# portador : 1729
# cromossomicas : 1729
# estado : 1729
# fragilidade : 1729
# imunologica : 1625
# asma, : 1374
# renais : 1349
# estagio : 1349
# avancado : 1349
# (graus : 1349
# 3, : 1349
# 4 : 1349
# imunodeficiencia, : 1257
# 5) : 1025
# asma : 742
# hepatica : 643
# imunodeficiencia : 518
# hematologica : 448
# imunossupressao, : 407
# 5), : 324
# gestante, : 209
# puerpera : 193
# (ate : 156
# 45 : 156
# dias : 156
# parto) : 148
# cronic : 148
# sindrome : 121
# imunologica, : 104
# down, : 81

# %%
word_freq = WordCloud().process_text(all_words_conditions)
dict(sorted(word_freq.items(), key=lambda item: item[1], reverse=True))
# Out:
# {'doencas cardiacas': 31911,
#  'cardiacas cronicas': 31911,
#  'cronicas doenca': 18011,
#  'doenca cardiovascular': 16909,
#  'cardiovascular cronica': 16909,
#  'doencas respiratorias': 12326,
#  'respiratorias cronicas': 12326,
#  'cronicas descompensadas': 12326,
#  'diabetes mellitu': 11943,
#  'diabetes doenca': 10795,
#  'outros doenca': 8740,
#  'cronicas diabetes': 8698,
#  'descompensadas doenca': 8294,
#  'cronica diabetes': 7861,
#  'cronica doenca': 7187,
#  'cronica outro': 5314,
#  'mellitus doenca': 4484,
#  'obesidade doenca': 3921,
#  'mellitus outro': 3363,
#  'outra pneumatopatia': 2967,
#  'pneumatopatia cronica': 2955,
#  'doenca neurologica': 2935,
#  'neurologica cronica': 2918,
#  'outros diabetes': 2702,
#  'obesidade outro': 2187,
#  'doenca renal': 2107,
#  'renal cronica': 2078,
#  'diabetes diabetes': 2040,
#  'descompensadas diabetes': 2009,
#  'imunossupressao doenca': 1845,
#  'portador de': 1729,
#  'de doencas': 1729,
#  'doencas cromossomicas': 1729,
#  'cromossomicas ou': 1729,
#  'ou estado': 1729,
#  'estado de': 1729,
#  'de fragilidade': 1729,
#  'fragilidade imunologica': 1729,
#  'gestante doenca': 1723,
#  'mellitus obesidade': 1647,
#  'cronicas obesidade': 1481,
#  'doencas renais': 1349,
#  'renais cronicas': 1349,
#  'cronicas em': 1349,
#  'em estagio': 1349,
#  'estagio avancado': 1349,
#  'avancado graus': 1349,
#  'graus ou': 1349,
#  'outros outros': 1313,
#  'cronica outra': 1238,
#  'imunologica doenca': 1190,
#  'obesidade diabetes': 1172,
#  'cronicas imunossupressao': 998,
#  'cronica asma': 974,
#  'imunodeficiencia outro': 916,
#  'diabetes obesidade': 913,
#  'mellitus outra': 838,
#  'ou doenca': 827,
#  'cronicas outros': 808,
#  'cronica imunodeficiencia': 795,
#  'mellitus diabetes': 786,
#  'outros obesidade': 721,
#  'doenca hepatica': 643,
#  'hepatica cronica': 638,
#  'asma diabetes': 631,
#  'imunodeficiencia doenca': 593,
#  'gestante diabetes': 557,
#  'diabetes imunossupressao': 553,
#  'cronicas portador': 495,
#  'outros gestante': 465,
#  'imunossupressao diabetes': 456,
#  'diabetes gestante': 448,
#  'doenca hematologica': 448,
#  'descompensadas obesidade': 438,
#  'obesidade obesidade': 428,
#  'descompensadas imunossupressao': 426,
#  'mellitus imunodeficiencia': 386,
#  'diabetes outros': 366,
#  'asma outro': 365,
#  'hematologica cronica': 363,
#  'outros asma': 357,
#  'descompensadas gestante': 345,
#  'descompensadas outros': 339,
#  'asma obesidade': 268,
#  'diabetes portador': 264,
#  'outros imunossupressao': 257,
#  'outros outra': 244,
#  'obesidade gestante': 243,
#  'cronica gestante': 242,
#  'imunologica diabetes': 240,
#  'descompensadas portador': 230,
#  'imunossupressao portador': 229,
#  'cronicas asma': 221,
#  'gestante obesidade': 214,
#  'cronicas outra': 195,
#  'outros imunodeficiencia': 185,
#  'gestante gestante': 171,
#  'obesidade imunossupressao': 159,
#  'puerpera ate': 156,
#  'ate dias': 156,
#  'cronica imunossupressao': 154,
#  'asma outra': 152,
#  'cronicas imunodeficiencia': 129,
#  'imunodeficiencia obesidade': 129,
#  'sindrome de': 121,
#  'outro doenca': 114,
#  'diabetes asma': 112,
#  'imunossupressao imunossupressao': 102,
#  'imunossupressao gestante': 98,
#  'ou imunossupressao': 92,
#  'obesidade portador': 87,
#  'parto doenca': 85,
#  'hematologica cronic': 85,
#  'diabetes outra': 82,
#  'cronic doenca': 82,
#  'ou portador': 78,
#  'gestante imunossupressao': 75,
#  'imunodeficiencia diabetes': 65,
#  'imunologica portador': 61,
#  'cronica portador': 61,
#  'imunologica imunossupressao': 59,
#  'parto': 57,
#  'asma imunodeficiencia': 57,
#  'diabetes imunodeficiencia': 56,
#  'gestante asma': 52,
#  'outros puerpera': 51,
#  'gestante puerpera': 35,
#  'cronica imunodeficienci': 33,
#  'de alto': 33,
#  'alto risco': 33,
#  'ou outros': 30,
#  'outro diabetes': 29,
#  'renal cronic': 29,
#  'risco doenca': 23,
#  'cronica puerpera': 22,
#  'obesidad': 20,
#  'mellitu doenca': 19,
#  'neurologica cronic': 17,
#  'outro outros': 16,
#  'parto gestante': 14,
#  'asma sindrome': 13,
#  'pneumatopatia cronic': 12,
#  'outro obesidade': 10,
#  'outro imunossupressao': 9,
#  'outro gestante': 7,
#  'mellitu diabetes': 7,
#  'imunodeficiencia obesidad': 6,
#  'asm': 5,
#  'outro imunodeficiencia': 5,
#  'imunodeficienci': 4,
#  'outro asma': 4,
#  'cronicas sindrome': 4,
#  'ou outra': 3,
#  'mellitu obesidade': 3,
#  'puerpera': 2,
#  'mellitu outra': 2,
#  'mellitu asma': 2,
#  'outro outra': 1,
#  'mellitu outros': 1,
#  'outro portador': 1,
#  'mellitu imunossupressao': 1}

# %% [markdown]
# Com a análise do campo textual, podemos visualizar algumas condições das quais podemos extrair. Devemos nos atentar para sinônimos, como 'doença cardíada' e 'doença cardiovascular', 'mellitus' ou 'diabetes. Outro ponto importante a se notar, são erros de digitação, como 'mellitu' ou 'asm', ou 'pneumopatia' como 'pneumatopatia'
#
# As doenças/condições que extrairemos a partir do campo `CONDICOES` são:
#
# - `CARDIOPATIA` = Doença cardiovascular ou doença cardíaca
# - `DIABETES` = Diabetes ou Mellitus
# - `DOENCA_RESPIRATORIA` = Asma, pneumopatia ou doença pulmonar
# - `DOENCA_NEUROLOGICA` = Doenças neurológicas crônicas
# - `PROBLEMA_RENAL` = Problemas renais
# - `OBESIDADE` = Obeso
# - `IMUNODEFICIENCIA` = Imunodeficiencia
# - `IMUNOSSUPRESSAO` =  imunossupressao
# - `GESTANTE` = Gestante
# - `HEPATITE` = Doenças hepáticas
# - `DOENCA_CROMOSSOMICA` = Sindrome de down
# - `HEMATOLOGICA` = Doenças hematológicas
# - `Puerpera` = Puerpera ou puerpério

# %%
df['CARDIOPATIA'] = ['SIM' if any(string in str(row) for string in ['cardiovascular', 'cardiacas']) else 
                        'NAO' for row in df['CONDICOES']]

df['DIABETES'] = ['SIM' if any(string in str(row) for string in ['diabetes', 'mellitus', 'mellitu']) else 
                  'NAO' for row in df['CONDICOES']]

df['DOENCA_RESPIRATORIA'] = ['SIM' if any(string in str(row) for string in ['respiratorias', 'asma', 'asm', 'pneumopatia', 'pneumatopatia']) else 
                         'NAO' for row in df['CONDICOES']]

df['DOENCA_NEUROLOGICA'] = ['SIM' if any(string in str(row) for string in ['neurologica']) else 
                      'NÃO' for row in df['CONDICOES']]

df['PROBLEMA_RENAL'] = ['SIM' if any(string in str(row) for string in ['renais']) else 
                      'NÃO' for row in df['CONDICOES']]

df['OBESIDADE'] = ['SIM' if any(string in str(row) for string in ['obesidade', 'obesidad']) else 
                   'NAO' for row in df['CONDICOES']]

df['IMUNODEFICIENCIA'] = ['SIM' if any(string in str(row) for string in ['imunodeficiencia']) else 
                         'NAO' for row in df['CONDICOES']]

df['IMUNOSSUPRESSAO'] = ['SIM' if any(string in str(row) for string in ['imunossupressao']) else 
                         'NAO' for row in df['CONDICOES']]

df['GESTANTE'] = ['SIM' if any(string in str(row) for string in ['gestante']) else 
                  'NAO' for row in df['CONDICOES']]

df['HEPATITE'] = ['SIM' if any(string in str(row) for string in ['hepatica', 'hepatite']) else 
                  'NAO' for row in df['CONDICOES']]

df['DOENCA_CROMOSSOMICA'] = ['SIM' if any(string in str(row) for string in ['cromossomicas', 'down']) else 
                  'NAO' for row in df['CONDICOES']]

df['PUERPERA'] = ['SIM' if any(string in str(row) for string in ['puerpera']) else 
                  'NAO' for row in df['CONDICOES']]

# %%
df.drop(columns=['CONDICOES'], inplace=True) # nao precisamos mais das condicoes
df.columns
# Out:
# Index(['SEXO', 'FAIXAETARIA', 'OBITO', 'FEBRE', 'TOSSE', 'GARGANTA',
#        'DISPNEIA', 'GESTANTE', 'RACA_COR', 'CARDIOPATIA', 'DIABETES',
#        'DOENCA_RESPIRATORIA', 'DOENCA_NEUROLOGICA', 'PROBLEMA_RENAL',
#        'OBESIDADE', 'IMUNODEFICIENCIA', 'IMUNOSSUPRESSAO', 'HEPATITE',
#        'DOENCA_CROMOSSOMICA', 'PUERPERA'],
#       dtype='object')

# %% [markdown]
# ## 3. Conclusão
#
# Após a limpeza e mineração de dados, vamos armazena-los a fim de que possam ser utilizados para treinar modelos preditivos.

# %%
df.to_csv("covid_11_marco_limpo.csv", sep=';', index=False)

# %% [markdown]
# ## [EXTRA] 4. Perfil de óbitos por covid no estado do Rio Grande do Sul
#
# Vamos analisar os sintomas/condicoes mais presentes nos pacientes que vieram a obito por covid.

# %%
df_obitos = df[df['OBITO'] == 1]

# %%
df_obitos
# Out:
#              SEXO FAIXAETARIA  OBITO FEBRE TOSSE GARGANTA DISPNEIA GESTANTE  \
# 161      Feminino   80 e mais      1   NAO   SIM      NAO      SIM      NAO
# 166      Feminino   80 e mais      1   NAO   NAO      NAO      SIM      NAO
# 181     Masculino   80 e mais      1   NAO   SIM      NAO      SIM      NAO
# 238     Masculino     50 a 59      1   NAO   SIM      NAO      SIM      NAO
# 284     Masculino   80 e mais      1   SIM   SIM      NAO      SIM      NAO
# ...           ...         ...    ...   ...   ...      ...      ...      ...
# 713442  Masculino     60 a 69      1   SIM   SIM      NAO      SIM      NAO
# 713461   Feminino     50 a 59      1   NAO   SIM      SIM      NAO      NAO
# 713492   Feminino     70 a 79      1   NAO   NAO      NAO      SIM      NAO
# 713519   Feminino   80 e mais      1   NAO   SIM      SIM      SIM      NAO
# 713596   Feminino     50 a 59      1   NAO   NAO      NAO      SIM      NAO
#
#              RACA_COR CARDIOPATIA DIABETES DOENCA_RESPIRATORIA  \
# 161            BRANCA         SIM      NAO                 NAO
# 166            BRANCA         NAO      NAO                 NAO
# 181     NAO INFORMADO         NAO      NAO                 NAO
# 238     NAO INFORMADO         SIM      SIM                 NAO
# 284            BRANCA         SIM      NAO                 NAO
# ...               ...         ...      ...                 ...
# 713442  NAO INFORMADO         NAO      NAO                 NAO
# 713461         BRANCA         SIM      SIM                 NAO
# 713492         BRANCA         SIM      SIM                 NAO
# 713519  NAO INFORMADO         NAO      SIM                 NAO
# 713596  NAO INFORMADO         NAO      NAO                 NAO
#
#        DOENCA_NEUROLOGICA PROBLEMA_RENAL OBESIDADE IMUNODEFICIENCIA  \
# 161                   NÃO            NÃO       NAO              NAO
# 166                   NÃO            NÃO       NAO              NAO
# 181                   NÃO            NÃO       NAO              NAO
# 238                   NÃO            NÃO       SIM              NAO
# 284                   NÃO            NÃO       NAO              NAO
# ...                   ...            ...       ...              ...
# 713442                NÃO            NÃO       NAO              SIM
# 713461                NÃO            NÃO       NAO              NAO
# 713492                NÃO            NÃO       NAO              NAO
# 713519                NÃO            NÃO       NAO              NAO
# 713596                NÃO            NÃO       SIM              NAO
#
#        IMUNOSSUPRESSAO HEPATITE DOENCA_CROMOSSOMICA PUERPERA
# 161                NAO      NAO                 NAO      NAO
# 166                NAO      NAO                 NAO      NAO
# 181                NAO      NAO                 NAO      NAO
# 238                NAO      NAO                 NAO      NAO
# 284                NAO      NAO                 NAO      NAO
# ...                ...      ...                 ...      ...
# 713442             NAO      NAO                 NAO      NAO
# 713461             NAO      NAO                 NAO      NAO
# 713492             NAO      NAO                 NAO      NAO
# 713519             NAO      NAO                 NAO      NAO
# 713596             NAO      NAO                 NAO      NAO
#
# [12483 rows x 20 columns]

# %%
def plot_distribution(dataset, cols=5, width=20, height=15, hspace=0.2, wspace=0.5):
    plt.style.use('seaborn-whitegrid')
    fig = plt.figure(figsize=(width,height))
    fig.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=wspace, hspace=hspace)
    rows = math.ceil(float(dataset.shape[1]) / cols)
    for i, column in enumerate(dataset.columns):
        ax = fig.add_subplot(rows, cols, i + 1)
        ax.set_title(column)
        if dataset.dtypes[column] == np.object:
            g = sns.countplot(y=column, data=dataset, palette="magma")
            substrings = [s.get_text()[:18] for s in g.get_yticklabels()]
            g.set(yticklabels=substrings)
            plt.xticks(rotation=25)
        else:
            g = sns.distplot(dataset[column])
            plt.xticks(rotation=25)
    
plot_distribution(df_obitos.drop(['OBITO'], axis=1), cols=3, width=20, height=20, hspace=0.45, wspace=0.5)

# %%
df_obitos['FEBRE'].value_counts().to_frame().head(1)
# Out:
#      FEBRE
# SIM   6568

# %%
for col in df_obitos.drop(['OBITO'], axis=1).columns:
    display(df_obitos[col].value_counts().to_frame().head(1))
# Out:
#            SEXO
# Masculino  6673
#            FAIXAETARIA
# 80 e mais         3750
#      FEBRE
# SIM   6568
#      TOSSE
# SIM   7454
#      GARGANTA
# NAO     10760
#      DISPNEIA
# SIM     10394
#      GESTANTE
# NAO     12470
#         RACA_COR
# BRANCA      7531
#      CARDIOPATIA
# SIM         6863
#      DIABETES
# NAO      7564
#      DOENCA_RESPIRATORIA
# NAO                10518
#      DOENCA_NEUROLOGICA
# NÃO               10759
#      PROBLEMA_RENAL
# NÃO           12483
#      OBESIDADE
# NAO      10817
#      IMUNODEFICIENCIA
# NAO             11607
#      IMUNOSSUPRESSAO
# NAO            12483
#      HEPATITE
# NAO     12150
#      DOENCA_CROMOSSOMICA
# NAO                12442
#      PUERPERA
# NAO     12459

# %% [markdown]
# Análise inciial do perfil do paciente que vem a óbito é:
#
# Paciente com:
#
# - `Sexo` = Masculino
# - `Faixa etária` = 80 anos ou mais
# - `Cor` = Branca
# - `Febre` = Sim
# - `Tosse` = Sim
# - `Dispneia` = Sim
# - `Cardiopatia` = Sim
# - `Dor de garganta` = Não
# - `Diabetes` = Não (embora tenha numero alto de óbitos aqui)
# - `Gestante` = Não
# - `Doença respiratória` = Não
# - `Doença neurologica` = Não
# - `Problema renal` = 'Não'
# - `Obesidade` = Não
# - `Imunodeficiencia` = Não
# - `Imunossupressão` = Não
# - `Hepatite` = Não
# - `Doença cromossomica` = Não
# - `Puerpera` = Não
#
#
# Ainda não tem a proporção de Valores relacionados a evolução para recuperado ou óbito, o que faz com que esse primeiro perfil não seja bastante confiável. Exemplo: Hepatite como maior valor sendo Não, porém uma pequena parcela apresenta hepatite. Portanto, não podemos concluir que ter hepatite significa que não vem a óbito, sem antes verificar a variavel isoladamente, da proporção da doença na coorte total.
